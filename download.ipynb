# %%
from ib_download import download

# %%
download()
# Out:
# serverVersion:151 connectionTime:b'20200214 18:38:56 SGT'
# client run()
# setting nextValidOrderId: 1
# requesting AAPL
# requesting AMZN
# requesting MSFT
# requesting GOOGL
# requesting FB
# requesting ADBE
# requesting CRM
# requesting NFLX
# requesting TSLA
# requesting BABA
# requesting NTES
# requesting BIDU
# requesting SE
# requesting NVDA
# requesting AVGO
# requesting INTC
# requesting MU
# requesting SMH
# requesting SPY
# requesting IWM
# requesting QQQ
# requesting JPM
# requesting BLK
# requesting WFC
# requesting MA
# requesting MS
# requesting V
# requesting GS
# requesting JNJ
# requesting MRK
# requesting PG
# requesting HD
# requesting MMM
# requesting WMT
# requesting BA
# requesting DIS
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ***___***___error___***___*** SYSTEM
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ***___***___error___***___*** SYSTEM
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ...
